# %% [markdown]
# <a href="https://colab.research.google.com/github/EugeneOny1/-civil-infrastructure-monitoring---CS-PROJECT-II/blob/feature-branch/01_Data_Preparation_and_Environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Vision-Based Civil Infrastructure Monitoring System
#
# ### Machine Learning Component
#
# **Model:** SSD-MobileNetV2
# **Framework:** TensorFlow Object Detection API
# **Development Environment:** Google Colab
# **Dataset Storage:** Google Drive
# **Version Control:** GitHub
#
# ### Target Defect Classes
#
# 1. Crack
# 2. Pothole
# 3. Surface deterioration

# %% [markdown]
# Environment Setup

# %%
# Environment setup

import os
import sys
import json
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image

# %%
print("Python version:", sys.version)
print("NumPy version:", np.__version__)
# Out:
# Python version: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# NumPy version: 2.1.3

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# GPU available: []

# %% [markdown]
# Connecting Google Drive

# %%
PROJECT_DIR = Path("/content/drive/MyDrive/CS PROJECT II")

DATA_DIR = PROJECT_DIR / "Data"

RAW_DIR = DATA_DIR / "Raw Data"
SELECTED_DIR = DATA_DIR / "Selected Data"
ANNOTATED_DIR = DATA_DIR / "Annotated Data"
PROCESSED_DIR = DATA_DIR / "Processed Data"

print("Project directory:", PROJECT_DIR)
# Out:
# Project directory: /content/drive/MyDrive/CS PROJECT II

# %%
directories = {
    "Project": PROJECT_DIR,
    "Raw Data": RAW_DIR,
    "Selected Data": SELECTED_DIR,
    "Annotated Data": ANNOTATED_DIR,
    "Processed Data": PROCESSED_DIR,
}

for name, path in directories.items():
    print(f"{name}: {'✓' if path.exists() else '✗'}")
# Out:
# Project: ✓
# Raw Data: ✓
# Selected Data: ✓
# Annotated Data: ✓
# Processed Data: ✓

# %% [markdown]
# ##Dataset Configuration

# %%
SDNET_DIR = RAW_DIR / "SDNET2018"
RDD_DIR = RAW_DIR / "RDD2022"
KENYAN_DIR = RAW_DIR / "Kenyan_Data"

print("SDNET2018:", SDNET_DIR.exists())
print("RDD2022:", RDD_DIR.exists())
print("Kenyan_Data:", KENYAN_DIR.exists())
# Out:
# SDNET2018: True
# RDD2022: True
# Kenyan_Data: True

# %%
SDNET_SELECTED = SELECTED_DIR / "SDNET2018"
RDD_SELECTED = SELECTED_DIR / "RDD2022"
KENYAN_SELECTED = SELECTED_DIR / "Kenyan_Data"

# %%
SDNET_ANNOTATED = ANNOTATED_DIR / "SDNET2018"
RDD_ANNOTATED = ANNOTATED_DIR / "RDD2022"
KENYAN_ANNOTATED = ANNOTATED_DIR / "Kenyan_Data"

# %% [markdown]
# ##Dataset Inspection

# %%
IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".JPG", ".JPEG", ".PNG"}

def count_images(directory):
    return sum(
        1 for path in Path(directory).rglob("*")
        if path.suffix in IMAGE_EXTENSIONS
    )

# %%
print("SDNET2018 images:", count_images(SDNET_DIR))
print("RDD2022 images:", count_images(RDD_DIR))
print("Kenyan images:", count_images(KENYAN_DIR))
# Out:
# SDNET2018 images: 56102
# RDD2022 images: 36984
# Kenyan images: 80

# %% [markdown]
# ##Inspecting Annotation Formats

# %%
def count_files(directory, extensions):
    directory = Path(directory)

    return sum(
        1
        for path in directory.rglob("*")
        if path.suffix.lower() in extensions
    )

# %%
XML_EXTENSIONS = {".xml"}
YOLO_EXTENSIONS = {".txt"}
JSON_EXTENSIONS = {".json"}

for name, directory in {
    "RDD2022": RDD_DIR,
    "SDNET2018": SDNET_DIR,
    "Kenyan_Data": KENYAN_DIR
}.items():

    print(f"\n{name}")
    print("-" * 30)

    print("Images:", count_images(directory))
    print("XML:", count_files(directory, XML_EXTENSIONS))
    print("YOLO TXT:", count_files(directory, YOLO_EXTENSIONS))
    print("JSON:", count_files(directory, JSON_EXTENSIONS))
# Out:
# RDD2022
# ------------------------------
# Images: 36984
# XML: 0
# YOLO TXT: 38386
# JSON: 0
#
# SDNET2018
# ------------------------------
# Images: 56102
# XML: 0
# YOLO TXT: 0
# JSON: 0
#
# Kenyan_Data
# ------------------------------
# Images: 80
# XML: 0
# YOLO TXT: 0
# JSON: 0

# %% [markdown]
# ##.xml Validation

# %%
def validate_voc_annotation(xml_path):
    ...
