# %% [markdown]
# # 06. Model Evaluation
#
# Computing mean Average Precision (mAP), Precision, Recall, and Confusion Matrix against test subset.

# %%
# Import baseline dependencies
import os
import numpy as np
print("Environment initialized.")
