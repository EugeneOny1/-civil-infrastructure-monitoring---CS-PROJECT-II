# %% [markdown]
# # 07. Inference Demo & Export
#
# Exporting SavedModel and TFLite weights to ../models/ directory for web application serving.

# %%
# Import baseline dependencies
import os
import numpy as np
print("Environment initialized.")
