# %% [markdown]
# # 02. Data Inspection and Exploratory Analysis
#
# Sourcing and verifying SDNET2018, RDD2020, and Nairobi field photography.

# %%
# Import baseline dependencies
import os
import numpy as np
print("Environment initialized.")
