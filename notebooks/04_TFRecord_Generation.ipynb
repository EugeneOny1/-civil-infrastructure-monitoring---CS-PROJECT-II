# %% [markdown]
# # 04. TFRecord Serialization
#
# Converting labeled imagery into train.record and val.record datasets (70:15:15 split).

# %%
# Import baseline dependencies
import os
import numpy as np
print("Environment initialized.")
