# %% [markdown]
# # 03. Annotation Validation
#
# Validating Pascal VOC XML / COCO bounding box labels for Cracks, Potholes, and Surface Deterioration.

# %%
# Import baseline dependencies
import os
import numpy as np
print("Environment initialized.")
