# %% [markdown]
# # 05. SSD-MobileNetV2 Model Training
#
# Transfer learning fine-tuning using pre-trained COCO weights and early stopping.

# %%
# Import baseline dependencies
import os
import numpy as np
print("Environment initialized.")
